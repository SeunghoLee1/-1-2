# %%
import time
from konlpy.tag import Okt
start_time = time.time()
f = open('어린왕자.txt')
cnt = {}
okt = Okt()
for row in f:
    k = row.strip()
    print(okt.pos(k))
print("--- %s seconds ---" %(time.time() - start_time))
# Out:
# [('여섯', 'Noun'), ('살', 'Noun'), ('적', 'Noun'), ('에', 'Josa'), ('나', 'Noun'), ('는', 'Josa'), ('"', 'Punctuation'), ('체험', 'Noun'), ('한', 'Josa'), ('이야기', 'Noun'), ('"', 'Punctuation'), ('라는', 'Josa'), ('제목', 'Noun'), ('의', 'Josa'), (',', 'Punctuation'), ('원시림', 'Noun'), ('에', 'Josa'), ('관', 'Noun'), ('한', 'Josa'), ('책', 'Noun'), ('에서', 'Josa'), ('기막힌', 'Adjective'), ('그림', 'Noun'), ('하나', 'Noun'), ('를', 'Josa'), ('본', 'Verb'), ('적', 'Noun'), ('이', 'Josa'), ('있다', 'Adjective'), ('.', 'Punctuation'), ('맹수', 'Noun'), ('를', 'Josa'), ('집어', 'Verb'), ('삼키고', 'Verb'), ('있는', 'Adjective'), ('보아', 'Noun'), ('구렁이', 'Noun'), ('그림이었다', 'Verb'), ('.', 'Punctuation'), ('위', 'Noun'), ('의', 'Josa'), ('그림', 'Noun'), ('은', 'Josa'), ('그것', 'Noun'), ('을', 'Josa'), ('옮겨', 'Verb'), ('그린', 'Noun'), ('것', 'Noun'), ('이다', 'Josa'), ('.', 'Punctuation')]
# [('그', 'Noun'), ('책', 'Noun'), ('에는', 'Josa'), ('이렇게', 'Adverb'), ('씌어', 'Noun'), ('있었다', 'Adjective'), ('.', 'Punctuation')]
# ...

# %%
f = open('어린왕자.txt')
