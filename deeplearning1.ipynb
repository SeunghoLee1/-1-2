# %%
# !pip install --upgrade pip
# !pip install konlpy
# !pip install pandas
# !pip install keras
# !pip install nltk
# Out:
# ...
#     100% |████████████████████████████████| 1.3MB 3.1MB/s ta 0:00:011
# ...
#   Found existing installation: pip 18.0
#     Uninstalling pip-18.0:
#       Successfully uninstalled pip-18.0
# ...
#     100% |████████████████████████████████| 19.4MB 47kB/s eta 0:00:011   26% |████████▍                       | 5.1MB 6.9MB/s eta 0:00:03
# ...
#     100% |████████████████████████████████| 174kB 5.1MB/s eta 0:00:01
# ...
#   Running setup.py bdist_wheel for JPype1 ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/0e/2b/e8/c0b818ac4b3d35104d35e48cdc7afe27fc06ea277feed2831a
# Successfully built JPype1
# ...

# %%
import pandas as pd
df = pd.read_csv('ratiodatamk2.csv', names = ["Adjective", "Adverb", "Alpha", "Conjunction", "Determiner", "Email", "Eomi", "Exclamation", "Foreign", "Hashtag", "Josa", "KoreanParticle", "Noun", "Number", "PreEomi", "Punctuation", "ScreenName", "Suffix", "Unknown", "Url", "Verb", "VerbPrefix", "class"], encoding = "cp949")

# %%
import pandas as pd
df = pd.read_csv('ratiodata.csv', names = ["Adjective", "Adverb", "Alpha", "Conjunction", "Determiner", "Email", "Eomi", "Exclamation", "Foreign", "Hashtag", "Josa", "KoreanParticle", "Noun", "Number", "PreEomi", "Punctuation", "ScreenName", "Suffix", "Unknown", "Url", "Verb", "VerbPrefix", "class"], encoding = "cp949")

# %%
print(df.head(5))
# Out:
#    Adjective  Adverb  Alpha  Conjunction  Determiner  Email  Eomi  \
# 0       1.92    0.48   2.40         0.00        0.00    0.0  0.00
# 1       3.26    0.87   0.00         0.11        0.65    0.0  0.11
# 2       3.26    0.87   0.00         0.11        0.65    0.0  0.11
# 3       2.02    0.81   1.21         0.00        0.00    0.0  0.00
# 4       1.40    0.28   2.80         0.00        0.28    0.0  0.00
#
#    Exclamation  Foreign  Hashtag  ...    Number  PreEomi  Punctuation  \
# 0          0.0     0.48        0  ...      3.85        0         6.25
# 1          0.0     3.91        0  ...      2.61        0         6.63
# 2          0.0     3.91        0  ...      2.61        0         6.63
# 3          0.0     2.42        0  ...      5.24        0         6.45
# 4          0.0     0.84        0  ...      3.08        0         4.76
#
#    ScreenName  Suffix  Unknown  Url   Verb  VerbPrefix  class
# 0           0    0.00        0    0  13.46        0.00      0
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy
import tensorflow as tf#seed 값 생성
import matplotlib.pyplot as plt
seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

#data 로드
dataset1 = numpy.loadtxt("ratiodata.csv", encoding = 'cp949', delimiter=",")
dataset2 = numpy.loadtxt("ratiodata-test.csv", encoding = 'cp949', delimiter=",")
X1 = dataset1[:,0:22]
Y1 = dataset1[:,22]
X2 = dataset2[:,0:22]
Y2 = dataset2[:,22]

#모델 설정
model = Sequential()
model.add(Dense(30, input_dim=22, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='relu'))

#모델 컴파일
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

#모델 실행+결과 그래프로 나타내기
hist = model.fit(X1, Y1, epochs=300, batch_size=10)
print("\n Accuracy: %.4f" % (model.evaluate(X1, Y1)[1]))
fig, acc_ax = plt.subplots()
acc_ax.plot(hist.history['acc'], 'b', label = 'accuracy(train)')

hist2 = model.fit(X2, Y2, epochs=300, batch_size=10)
print("\n Accuracy: %.4f" % (model.evaluate(X2, Y2)[1]))
acc_ax.plot(hist2.history['acc'], 'b', label = 'accuracy(test)', color = 'C0')

acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='upper left')


plt.show()
# Out:
# Epoch 1/300
# 43/43 [==============================] - 1s 27ms/step - loss: 6.7673 - acc: 0.0233
# Epoch 2/300
# 43/43 [==============================] - 0s 309us/step - loss: 4.3269 - acc: 0.1395
# Epoch 3/300
# 43/43 [==============================] - 0s 289us/step - loss: 2.8933 - acc: 0.4186
# Epoch 4/300
# 43/43 [==============================] - 0s 440us/step - loss: 2.2238 - acc: 0.5116
# Epoch 5/300
# 43/43 [==============================] - 0s 400us/step - loss: 1.7162 - acc: 0.5581
# Epoch 6/300
# 43/43 [==============================] - 0s 359us/step - loss: 1.3063 - acc: 0.4884
# Epoch 7/300
# 43/43 [==============================] - 0s 328us/step - loss: 1.2257 - acc: 0.4884
# Epoch 8/300
# 43/43 [==============================] - 0s 315us/step - loss: 0.7759 - acc: 0.4651
# Epoch 9/300
# 43/43 [==============================] - 0s 327us/step - loss: 0.7037 - acc: 0.4884
# Epoch 10/300
# 43/43 [==============================] - 0s 377us/step - loss: 0.5680 - acc: 0.4884
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy
import tensorflow as tf#seed 값 생성
import matplotlib.pyplot as plt
seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

#data 로드
dataset1 = numpy.loadtxt("ratiodatamk2.csv", encoding = 'cp949', delimiter=",")
dataset2 = numpy.loadtxt("radiodatamk2-test.csv", encoding = 'cp949', delimiter=",")
X1 = dataset1[:,0:22]
Y1 = dataset1[:,22]
X2 = dataset2[:,0:22]
Y2 = dataset2[:,22]

#모델 설정
model = Sequential()
model.add(Dense(30, input_dim=22, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='relu'))

#모델 컴파일
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

#모델 실행+결과 출력+결과 그래프로 나타내기
hist = model.fit(X1, Y1, epochs=300, batch_size=10)
print("\n Accuracy: %.4f" % (model.evaluate(X1, Y1)[1]))
fig, acc_ax = plt.subplots()
acc_ax.plot(hist.history['acc'], 'b', label = 'accuracy(train)')

hist2 = model.fit(X2, Y2, epochs=300, batch_size=10)
print("\n Accuracy: %.4f" % (model.evaluate(X2, Y2)[1]))
acc_ax.plot(hist2.history['acc'], 'b', label = 'accuracy(test)', color = 'C0')




acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='upper left')


plt.show()
# Out:
# Epoch 1/300
# 45/45 [==============================] - 1s 24ms/step - loss: 7.6507 - acc: 0.1333
# Epoch 2/300
# 45/45 [==============================] - 0s 269us/step - loss: 6.4845 - acc: 0.0889
# Epoch 3/300
# 45/45 [==============================] - 0s 253us/step - loss: 5.9955 - acc: 0.0889
# Epoch 4/300
# 45/45 [==============================] - 0s 256us/step - loss: 5.6921 - acc: 0.0667
# Epoch 5/300
# 45/45 [==============================] - 0s 255us/step - loss: 5.2099 - acc: 0.0667
# Epoch 6/300
# 45/45 [==============================] - 0s 271us/step - loss: 4.9931 - acc: 0.0889
# Epoch 7/300
# 45/45 [==============================] - 0s 313us/step - loss: 4.6958 - acc: 0.1111
# Epoch 8/300
# 45/45 [==============================] - 0s 268us/step - loss: 4.5276 - acc: 0.1111
# Epoch 9/300
# 45/45 [==============================] - 0s 305us/step - loss: 4.3487 - acc: 0.1111
# Epoch 10/300
# 45/45 [==============================] - 0s 296us/step - loss: 4.2196 - acc: 0.1111
# ...
