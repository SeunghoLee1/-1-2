# %%
# !pip install --upgrade pip
# !pip install konlpy
# !pip install pandas
# !pip install keras
# !pip install nltk
# Out:
# Requirement already up-to-date: pip in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (18.1)
# ...
#     100% |████████████████████████████████| 19.4MB 90kB/s  eta 0:00:01              | 993kB 24.9MB/s eta 0:00:01.6MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 174kB 4.7MB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for JPype1 ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/0e/2b/e8/c0b818ac4b3d35104d35e48cdc7afe27fc06ea277feed2831a
# Successfully built JPype1
# ...

# %%
import pandas as pd
df = pd.read_csv('데이터(기사).csv', names = ["nounR","verbR", "adjecR", "adverR", "conjuR", "numbR", "n1", "n2", "n3", "v1", "v2", "v3", "a1", "a2", "a3", "ad1", "ad2", "ad3","c1", "c2", "c3", "class"], encoding = 'cp949')

# %%
import pandas as pd
df = pd.read_csv('데이터(기사)-단어없음.csv', names = ["nounR","verbR", "adjecR", "adverR", "conjuR", "numbR", "class"], encoding = 'cp949')

# %%
import pandas as pd
df = pd.read_csv('ratiodata.csv', names = ["Adjective", "Adverb", "Alpha", "Conjunction", "Determiner", "Email", "Eomi", "Exclamation", "Foreign", "Hashtag", "Josa", "KoreanParticle", "Noun", "Number", "PreEomi", "Punctuation", "ScreenName", "Suffix", "Unknown", "Url", "Verb", "VerbPrefix", "class"], encoding = "cp949")

# %%
import pandas as pd
df = pd.read_csv('ratiodatamk2.csv', names = ["Adjective", "Adverb", "Alpha", "Conjunction", "Determiner", "Email", "Eomi", "Exclamation", "Foreign", "Hashtag", "Josa", "KoreanParticle", "Noun", "Number", "PreEomi", "Punctuation", "ScreenName", "Suffix", "Unknown", "Url", "Verb", "VerbPrefix", "class"], encoding = 'cp949')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-ff2f3eac1650> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('ratiodatamk2.csv', names = ["Adjective", "Adverb", "Alpha", "Conjunction", "Determiner", "Email", "Eomi", "Exclamation", "Foreign", "Hashtag", "Josa", "KoreanParticle", "Noun", "Number", "PreEomi", "Punctuation", "ScreenName", "Suffix", "Unknown", "Url", "Verb", "VerbPrefix", "class"], encoding = 'cp949')
#
# ...

# %%
print(df.head(5))
# Out:
#       Adjective  Adverb  Alpha  Conjunction  Determiner  Email  Eomi  \
# 1.92       0.48    2.40   0.00         0.00         0.0   0.00   0.0
# 3.26       0.87    0.00   0.11         0.65         0.0   0.11   0.0
# 3.26       0.87    0.00   0.11         0.65         0.0   0.11   0.0
# 2.02       0.81    1.21   0.00         0.00         0.0   0.00   0.0
# 1.40       0.28    2.80   0.00         0.28         0.0   0.00   0.0
#
#       Exclamation  Foreign  Hashtag     ...      Noun  Number  PreEomi  \
# 1.92         0.48        0    21.63     ...      3.85       0     6.25
# 3.26         3.91        0    20.11     ...      2.61       0     6.63
# 3.26         3.91        0    20.11     ...      2.61       0     6.63
# 2.02         2.42        0    19.35     ...      5.24       0     6.45
# 1.40         0.84        0    23.25     ...      3.08       0     4.76
#
#       Punctuation  ScreenName  Suffix  Unknown    Url  Verb  VerbPrefix
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy
import tensorflow as tf#seed 값 생성
seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

#data 로드
dataset = numpy.loadtxt("ratiodata.csv", encoding = 'cp949', delimiter=",")
X = dataset[:,0:22]
Y = dataset[:,22]

#data 전처리

#모델 설정
model = Sequential()
model.add(Dense(12, input_dim=22, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

#모델 컴파일
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

#모델 실행
model.fit(X, Y, epochs=300, batch_size=10)

#결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# Using TensorFlow backend.
# Epoch 1/300
# 67/67 [==============================] - 1s 10ms/step - loss: 0.5367 - acc: 0.4627
# Epoch 2/300
# 67/67 [==============================] - 0s 398us/step - loss: 0.5354 - acc: 0.4627
# Epoch 3/300
# 67/67 [==============================] - 0s 479us/step - loss: 0.5322 - acc: 0.4627
# Epoch 4/300
# 67/67 [==============================] - 0s 403us/step - loss: 0.5236 - acc: 0.4627
# Epoch 5/300
# 67/67 [==============================] - 0s 484us/step - loss: 0.4986 - acc: 0.4627
# Epoch 6/300
# 67/67 [==============================] - 0s 489us/step - loss: 0.4457 - acc: 0.4627
# Epoch 7/300
# 67/67 [==============================] - 0s 415us/step - loss: 0.3581 - acc: 0.4627
# Epoch 8/300
# 67/67 [==============================] - 0s 365us/step - loss: 0.2958 - acc: 0.4627
# Epoch 9/300
# 67/67 [==============================] - 0s 338us/step - loss: 0.2595 - acc: 0.6418
# Epoch 10/300
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy
import tensorflow as tf#seed 값 생성
seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

#data 로드
dataset = numpy.loadtxt("ratiodatamk2.csv", encoding = 'cp949', delimiter=",")
X = dataset[:,0:22]
Y = dataset[:,22]

#data 전처리

#모델 설정
model = Sequential()
model.add(Dense(12, input_dim=22, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

#모델 컴파일
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

#모델 실행
model.fit(X, Y, epochs=300, batch_size=10)

#결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# Epoch 1/300
# 67/67 [==============================] - 1s 12ms/step - loss: 5.5231 - acc: 0.1343
# Epoch 2/300
# 67/67 [==============================] - 0s 492us/step - loss: 5.5226 - acc: 0.1343
# Epoch 3/300
# 67/67 [==============================] - 0s 485us/step - loss: 5.5225 - acc: 0.1343
# Epoch 4/300
# 67/67 [==============================] - 0s 415us/step - loss: 5.5225 - acc: 0.1343
# Epoch 5/300
# 67/67 [==============================] - 0s 564us/step - loss: 5.5224 - acc: 0.1343
# Epoch 6/300
# 67/67 [==============================] - 0s 647us/step - loss: 5.5224 - acc: 0.1343
# Epoch 7/300
# 67/67 [==============================] - 0s 323us/step - loss: 5.5224 - acc: 0.1343
# Epoch 8/300
# 67/67 [==============================] - 0s 388us/step - loss: 5.5224 - acc: 0.1343
# Epoch 9/300
# 67/67 [==============================] - 0s 502us/step - loss: 5.5224 - acc: 0.1343
# Epoch 10/300
# 67/67 [==============================] - 0s 380us/step - loss: 5.5224 - acc: 0.1343
# ...
